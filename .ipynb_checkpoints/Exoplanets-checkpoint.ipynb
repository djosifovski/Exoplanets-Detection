# %% [markdown]
# # Exoplanet Detection

# %% [markdown]
# ### Table of Contents
#
# * [I. Import Libraries](#chapter1)
# * [II. Read Data Set](#chapter2)
# * [III. Data Analysis](#chapter3)
#     * [III.1 Summary of Data Frame](#section3_1)
#     * [III.2 Univariate Analysis](#section3_2)
#     * [III.3 Statistical graphical techniques](#section3_3)
#     * [III.4 Data Cleaning](#section3_4)
#     * [III.5 Class Distribution](#section3_5)
#     * [III.6 Train/Test Split](#section3_6)
# * [IV. Preprocessing](#chapter4)
#     * [IV.1 Feature Engineering](#section4_1)
#     * [IV.2 Feature Selection](#section4_2)
#     * [IV.3 Pipeline](#section4_3)
# * [V. Modeling](#chapter5)
#     * [V.1 Model Training and Hyperparameter Optimization](#section5_1)
#     * [V.2 Model Evaluation](#section5_2)
#         * [V.2.1 Summary of model evaluation](#section5_2_1)
# * [VI. Discovering exoplanets with the chosen model](#chapter6)
# * [VII. References](#chapter7)

# %% [markdown]
# # I. Import Libraries<a class="anchor" id="chapter1"></a>

# %%
# Data Manipulation 
import numpy as np
import pandas as pd
from scipy import stats

# Visualization 
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
plt.style.use('seaborn-whitegrid')

# Feature Engineering and Feature Selection
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.pipeline import Pipeline

# Model Training
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import StackingCVClassifier

# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV, cross_val_score

# Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, \
roc_auc_score, roc_curve
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# Managing Warnings 
import warnings
warnings.filterwarnings('ignore')

# Plot the Figures Inline
# %matplotlib inline

# %% [markdown]
# # II. Read Data Set<a class="anchor" id="chapter2"></a>

# %%
path = 'data/'
cumulative = pd.read_csv(path + 'cumulative_2020.08.29_14.21.21.csv', skiprows=53)

cumulative
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %% [markdown]
# The data set is downloaded from the website of NASA Exoplanet Archive \[[1](#ref1)\].
#
# A detailed description of the features can be found in \[[2](#ref2)\].
#
# The first 53 columns contain descriptions of the features.

# %% [markdown]
# # III. Data Analysis<a class="anchor" id="chapter3"></a>

# %% [markdown]
# ## III.1 Summary of Data Frame<a class="anchor" id="section3_1"></a>

# %%
cumulative.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   kepler_name        2308 non-null   object
#  3   koi_disposition    9564 non-null   object
#  4   koi_pdisposition   9564 non-null   object
#  5   koi_score          8054 non-null   float64
#  6   koi_fpflag_nt      9564 non-null   int64
#  7   koi_fpflag_ss      9564 non-null   int64
#  8   koi_fpflag_co      9564 non-null   int64
#  9   koi_fpflag_ec      9564 non-null   int64
#  10  koi_period         9564 non-null   float64
#  11  koi_period_err1    9110 non-null   float64
#  12  koi_period_err2    9110 non-null   float64
#  13  koi_time0bk        9564 non-null   float64
#  14  koi_time0bk_err1   9110 non-null   float64
#  15  koi_time0bk_err2   9110 non-null   float64
# ...

# %% [markdown]
# In the following cells, missing data is explored in more detail.

# %%
msno.matrix(cumulative, figsize=(25,5))
plt.show()

# %%
msno.bar(cumulative, figsize=(25,5))
plt.show()

# %% [markdown]
# ## III.2 Univariate Analysis<a class="anchor" id="section3_2"></a>

# %%
num = cumulative.loc[:, cumulative.dtypes != 'object']
cat = cumulative.loc[:, cumulative.dtypes == 'object']

# %% [markdown]
# There are numerical and categorical features in the data set. Thus, they are separated in two DataFrames so that different statistical characteristics of each of the features can be calculated.

# %%
num.shape, cat.shape
# Out:
# ((9564, 44), (9564, 5))

# %%
num_summary = num.describe()
num_summary.loc['variance'] = num.var()
num_summary.loc['skewness'] = num.skew()
num_summary.loc['kurtosis'] = num.kurtosis()
num_summary.loc['IQR'] = num.quantile(q=0.75) - num.quantile(q=0.25)
num_summary.loc['range'] = num.max() - num.min()

if num.shape[1] <= 10:
    display(num_summary)
else:
    display(num_summary.transpose())
# Out:
#                     count          mean           std           min  \
# kepid              9564.0  7.690628e+06  2.653459e+06  7.574500e+05
# koi_score          8054.0  4.808294e-01  4.769285e-01  0.000000e+00
# koi_fpflag_nt      9564.0  2.085947e-01  4.767290e+00  0.000000e+00
# koi_fpflag_ss      9564.0  2.327478e-01  4.226049e-01  0.000000e+00
# koi_fpflag_co      9564.0  1.975115e-01  3.981423e-01  0.000000e+00
# koi_fpflag_ec      9564.0  1.200335e-01  3.250176e-01  0.000000e+00
# koi_period         9564.0  7.567136e+01  1.334744e+03  2.418425e-01
# koi_period_err1    9110.0  2.147864e-03  8.236369e-03  0.000000e+00
# koi_period_err2    9110.0 -2.147864e-03  8.236369e-03 -1.725000e-01
# koi_time0bk        9564.0  1.661833e+02  6.791896e+01  1.205159e+02
# koi_time0bk_err1   9110.0  9.932561e-03  2.309741e-02  8.700000e-06
# koi_time0bk_err2   9110.0 -9.932561e-03  2.309741e-02 -5.690000e-01
# koi_impact         9201.0  7.351055e-01  3.348832e+00  0.000000e+00
# ...

# %%
rejected = 0
accepted = 0

for feature in num.columns:
    if num[feature].dropna().shape[0] >= 3: # Data must be at least length 3.
        p_value = stats.shapiro(num[feature].dropna())[1]
        if p_value <= 0.05:
            print(f'{feature} --- Null hypothesis of normality is rejected')
            rejected += 1
        else:
            print(f'{feature} --- Null hypothesis of normality is accepted')
            accepted += 1

print('\n')
print(f'Rejected hypotheses: {rejected}')
print(f'Accepted hypotheses: {accepted}')
# Out:
# kepid --- Null hypothesis of normality is rejected
# koi_score --- Null hypothesis of normality is rejected
# koi_fpflag_nt --- Null hypothesis of normality is rejected
# koi_fpflag_ss --- Null hypothesis of normality is rejected
# koi_fpflag_co --- Null hypothesis of normality is rejected
# koi_fpflag_ec --- Null hypothesis of normality is rejected
# koi_period --- Null hypothesis of normality is rejected
# koi_period_err1 --- Null hypothesis of normality is rejected
# koi_period_err2 --- Null hypothesis of normality is rejected
# koi_time0bk --- Null hypothesis of normality is rejected
# koi_time0bk_err1 --- Null hypothesis of normality is rejected
# koi_time0bk_err2 --- Null hypothesis of normality is rejected
# koi_impact --- Null hypothesis of normality is rejected
# koi_impact_err1 --- Null hypothesis of normality is rejected
# koi_impact_err2 --- Null hypothesis of normality is rejected
# koi_duration --- Null hypothesis of normality is rejected
# ...

# %% [markdown]
# The null hypothesis of the Shapiro-Wilk test is used to estimate the probablity that the data is normally distributed. As it turns out, none of the data is normally distributed.

# %%
cat_summary = cat.describe()
if cat.shape[1] <= 10:
    display(cat_summary)
else:
    display(cat_summary.transpose())
# Out:
#        kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# count        9564          2308            9564             9564
# unique       9564          2308               3                2
# top     K00752.01  Kepler-227 b  FALSE POSITIVE   FALSE POSITIVE
# freq            1             1            4840             4847
#
#        koi_tce_delivname
# count               9218
# unique                 3
# top      q1_q17_dr25_tce
# freq                8054

# %%
for column in cat.columns:
    unique_values = cat[column].unique()
    number_values = len(unique_values)
    if number_values <= 10:
        print(f'Unique values for feature {column}: {number_values} -- {unique_values}')
    else:
        print(f'Unique values for feature {column}: {number_values}')
# Out:
# Unique values for feature kepoi_name: 9564
# Unique values for feature kepler_name: 2309
# Unique values for feature koi_disposition: 3 -- ['CONFIRMED' 'CANDIDATE' 'FALSE POSITIVE']
# Unique values for feature koi_pdisposition: 2 -- ['CANDIDATE' 'FALSE POSITIVE']
# Unique values for feature koi_tce_delivname: 4 -- ['q1_q17_dr25_tce' 'q1_q16_tce' nan 'q1_q17_dr24_tce']

# %% [markdown]
# ## III.3 Statistical graphical techniques<a class="anchor" id="section3_3"></a>

# %% [markdown]
# ### III.3.1 Univariate numerical and categorical data

# %%
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = np.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)
    
plot_distribution(cumulative, cols=3, width=20, height=40, hspace=0.9, wspace=0.5)

# %% [markdown]
# As expected, the data is not normally distributed. There are outliers in almost every numerical features, they are more or less normally distributed which suggest that feature scaling should be applied.
#
# The code is taken from [here](https://github.com/dformoso/sklearn-classification/blob/master/Data%20Science%20Workbook%20-%20Census%20Income%20Dataset.ipynb).

# %% [markdown]
# ### III.3.2 Bivariate numerical data

# %%
# Create a correlation plot of both datasets.
fig = plt.figure(figsize=(10,10)) 

# Generate a mask for the upper triangle
mask = np.zeros_like(cumulative.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(cumulative.corr(), 
            vmin=-1, vmax=1, 
            square=True, 
            cmap=sns.color_palette("RdBu_r", 100), 
            mask=mask,
            linewidths=.5);

# %% [markdown]
# The code is taken from [here](https://github.com/dformoso/sklearn-classification/blob/master/Data%20Science%20Workbook%20-%20Census%20Income%20Dataset.ipynb).

# %% [markdown]
# ## III.4 Data Cleaning<a class="anchor" id="section3_4"></a>

# %%
exoplanets = cumulative.loc[cumulative['koi_disposition'] != 'CANDIDATE']
candidates = cumulative.loc[cumulative['koi_disposition'] == 'CANDIDATE']

# %% [markdown]
# From EDA, the target feature had three values: `CONFIRMED`, `FALSE POSITIVE`, and `CANDIDATE`. The data set is separated in two parts, where the first contains the examples that labeled, and the second contains the examples that need to be classified with the models that are going to be built.

# %%
exoplanets.drop(columns=['kepid', 'kepoi_name', 'kepler_name', 'koi_pdisposition', 'koi_tce_delivname'], inplace=True)

# %% [markdown]
# The categorical data don't carry any information because they are features created by the scientist to uniquely identify the astronomical objects that were detected with the space telescope. Thus, they can be removed.

# %%
exoplanets.drop(columns = ['koi_teq_err1', 'koi_teq_err2'], inplace=True)

# %% [markdown]
# These two features don't have any value, and they are removed. This is done before droping the other sporadic missing values in the data set, because if the method `dropna()` is applied before dropping them, the whole data set will be removed.

# %%
n_complete = exoplanets.shape[0]

exoplanets.dropna(axis=0, inplace=True)

n_dropped = exoplanets.shape[0]

dropped_percentage = np.round((1 - n_dropped/n_complete)*100, 4)
print(f'Dropped rows: {n_complete-n_dropped} --- {dropped_percentage:.4f} %')
# Out:
# Dropped rows: 1130 --- 15.8130 %

# %% [markdown]
# Because the data set is relatively big, the missing values are removed.

# %% [markdown]
# ## III.5 Class Distribution<a class="anchor" id="section3_5"></a>

# %%
def get_class_counts(df, feature):
    '''
    Function that returns the number of examples in each class
    '''
    classes = df[feature].unique()
    class_counts = dict()
    
    for c in classes:
        counts = df[df[feature] == c].shape[0]
        class_counts.update({c: counts})
    
    return class_counts

def get_class_proportions(df, feature):
    '''
    Function that returns the ratio of examples in each class (confirmed and false positive)
    '''
    class_counts = get_class_counts(df, feature)
    
    classes = df[feature].unique()
    total_examples = df[feature].shape[0]
    class_ratios = dict()
    
    for c in classes:
        ratio = np.round(df[df[feature] == c].shape[0] / total_examples, 4)*100
        class_ratios.update({c: ratio})
    
    return class_ratios

# %%
exoplanets_counts = get_class_counts(df=exoplanets, feature='koi_disposition')
exoplanets_ratios = get_class_proportions(df=exoplanets, feature='koi_disposition')

print(f'Data set class counts: {exoplanets_counts}')
print(f'Data set class ratios: {exoplanets_ratios}')
# Out:
# Data set class counts: {'CONFIRMED': 2281, 'FALSE POSITIVE': 3735}
# Data set class ratios: {'CONFIRMED': 37.92, 'FALSE POSITIVE': 62.08}

# %% [markdown]
# Important thing to check when dealing with classification is if the data set is balanced or imbalanced. As it turns out, it is imbalanced, and stratification need sto be used.

# %% [markdown]
# ## III.6 Train/Test Split<a class="anchor" id="section3_6"></a>

# %%
test_size = 0.17

train, test = train_test_split(exoplanets, test_size=test_size, random_state=0, stratify=exoplanets['koi_disposition'])

# %%
train.shape[0], test.shape[0]
# Out:
# (4993, 1023)

# %%
train_class_counts = get_class_counts(df=train, feature='koi_disposition')
test_class_counts = get_class_counts(df=test, feature='koi_disposition')

train_class_ratios = get_class_proportions(df=train, feature='koi_disposition')
test_class_ratios = get_class_proportions(df=test, feature='koi_disposition')

print("Train class counts:", train_class_counts)
print("Test class counts:", test_class_counts)

print("Train class proportions:", train_class_ratios)
print("Test class proportions:", test_class_ratios)
# Out:
# Train class counts: {'FALSE POSITIVE': 3100, 'CONFIRMED': 1893}
# Test class counts: {'FALSE POSITIVE': 635, 'CONFIRMED': 388}
# Train class proportions: {'FALSE POSITIVE': 62.09, 'CONFIRMED': 37.91}
# Test class proportions: {'FALSE POSITIVE': 62.07, 'CONFIRMED': 37.93}

# %%
def X_y_split(df, target):
    '''
    Function to split the data set in data and target
    '''
    X = df.drop(target, axis=1)
    y = df[target]
    return X, y

# %%
target = 'koi_disposition'

X_train, y_train = X_y_split(train, target)
X_test, y_test = X_y_split(test, target)

# %% [markdown]
# # IV. Preprocessing<a class="anchor" id="chapter4"></a>

# %% [markdown]
# ## IV.1 Feature engineering<a class="anchor" id="section4_1"></a>

# %% [markdown]
# ### IV.1.1 Min-Max Normalization

# %%
mm = MinMaxScaler()

# %%
X_train = pd.DataFrame(data=mm.fit_transform(X_train), columns=X_train.columns)

# %%
X_train.hist(bins=40, figsize=(20,20))
plt.show()

# %% [markdown]
# ### IV.1.2 Label Encoding

# %%
y_train
# Out:
# 7928    FALSE POSITIVE
# 308          CONFIRMED
# 1575         CONFIRMED
# 3159         CONFIRMED
# 8700    FALSE POSITIVE
#              ...
# 8582    FALSE POSITIVE
# 6795    FALSE POSITIVE
# 1246    FALSE POSITIVE
# 2859         CONFIRMED
# 4672    FALSE POSITIVE
# Name: koi_disposition, Length: 4993, dtype: object

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {'CONFIRMED': 0, 'FALSE POSITIVE': 1}

# %%
y_train = le.transform(y_train)

# %%
y_train
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %% [markdown]
# ### IV.2 Feature selection<a class="anchor" id="section4_2"></a>

# %%
forest = ExtraTreesClassifier(n_estimators=50, random_state=0)
forest.fit(X_train, y_train)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# %%
importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)

# %%
importances
# Out:
# koi_score            0.434568
# koi_fpflag_ss        0.172580
# koi_fpflag_co        0.123422
# koi_fpflag_ec        0.053146
# koi_fpflag_nt        0.030665
# koi_steff_err1       0.018142
# koi_steff_err2       0.013544
# koi_prad             0.013453
# koi_depth            0.011025
# koi_tce_plnt_num     0.009502
# koi_prad_err1        0.009170
# koi_period           0.008291
# koi_teq              0.008272
# koi_duration_err2    0.007935
# koi_model_snr        0.007106
# koi_impact           0.006862
# koi_impact_err1      0.005990
# koi_slogg_err2       0.005511
# koi_slogg            0.005394
# koi_duration_err1    0.004956
# koi_time0bk_err2     0.003671
# ra                   0.003475
# koi_duration         0.003190
# koi_prad_err2        0.003142
# koi_insol            0.003050
# koi_period_err2      0.002964
# koi_depth_err2       0.002922
# koi_depth_err1       0.002897
# koi_insol_err2       0.002638
# koi_slogg_err1       0.002585
# koi_time0bk_err1     0.002298
# ...

# %%
fig, ax = plt.subplots(figsize=(18, 6), dpi=80)
importances.plot.bar(yerr=std[indices], ax=ax)
ax.set_title('Feature importances using ExtraTreesClassifier')
ax.set_ylabel('Feature Importance')
plt.show()

# %%
selection = SelectFromModel(forest, threshold='median', prefit=True)
X_train = selection.transform(X_train)
X_train.shape
# Out:
# (4993, 21)

# %% [markdown]
# There are a lot of features, and not all of them are relevant for modeling. The most important features are determined with extra-trees classifier, and the threshold is the median of the feature importances.

# %%
X_train = pd.DataFrame(data=X_train, columns=importances.index[0:X_train.shape[1]])

# %%
X_train.head()
# Out:
#    koi_score  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_fpflag_nt  \
# 0      0.000            0.0            1.0            0.0            0.0
# 1      1.000            0.0            0.0            0.0            0.0
# 2      1.000            0.0            0.0            0.0            0.0
# 3      0.999            0.0            0.0            0.0            0.0
# 4      0.000            0.0            1.0            0.0            0.0
#
#    koi_steff_err1  koi_steff_err2  koi_prad  koi_depth  koi_tce_plnt_num  ...  \
# 0        0.023350        0.999809  0.046005   0.001005          0.001025  ...
# 1        0.019293        0.996333  0.011490   0.001941          0.008568  ...
# 2        0.004645        0.998333  0.038016   0.000058          0.003667  ...
# 3        0.008947        0.994118  0.039856   0.000292          0.010864  ...
# 4        0.000537        0.999809  0.020961   0.000222          0.001006  ...
#
# ...

# %% [markdown]
# ### IV.3 Pipeline<a class="anchor" id="section4_3"></a>

# %%
pipeline = Pipeline([
    ('min-max-normalization', MinMaxScaler()),
    ('feature-selection', SelectFromModel(ExtraTreesClassifier(n_estimators=50, random_state=0), threshold='median'))
])

# %% [markdown]
# The preprocessing of the features is summarized in a pipeline.

# %%
train.head()
# Out:
#      koi_disposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 7928  FALSE POSITIVE      0.000              0              1              0
# 308        CONFIRMED      1.000              0              0              0
# 1575       CONFIRMED      1.000              0              0              0
# 3159       CONFIRMED      0.999              0              0              0
# 8700  FALSE POSITIVE      0.000              0              1              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 7928              0   25.150788     3.878000e-06    -3.878000e-06
# 308               0   20.834267     5.358000e-05    -5.358000e-05
# 1575              0    5.248668     6.064000e-06    -6.064000e-06
# 3159              0    9.825785     3.793000e-05    -3.793000e-05
# 8700              0    0.878803     1.290000e-07    -1.290000e-07
#
#       koi_time0bk  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
X_train = pipeline.fit_transform(train.drop('koi_disposition', axis=1), train['koi_disposition'])
X_test = pipeline.transform(test.drop('koi_disposition', axis=1))

y_train = le.transform(train['koi_disposition'])
y_test = le.transform(test['koi_disposition'])

# %% [markdown]
# # V. Modeling<a class="anchor" id="chapter5"></a>

# %% [markdown]
# ## V.1 Model Training and Hyperparameter Optimization<a class="anchor" id="section5_1"></a>

# %%
def train_classifier(model, X, y, shuffle_split):
    """
    Function to fit a classifier to the training data, and evaluate performance on train set
    """
    print(f'Trainig of model: {model.__class__.__name__}')
    model.fit(X, y)
    
    scores = cross_val_score(model, X, y, cv=shuffle_split, n_jobs=-1)
    
    score = np.round(scores.mean(), 4)
    
    print(f'Parameters: {model.get_params()}')
    print(f'Mean cross-validated accuracy: {score}')
    
    return score

# %%
def grid_search(model, X, y, param_grid, shuffle_split):
    '''
    Function to tune hyper-parameters of models with grid search
    '''
    grid_search = GridSearchCV(model,
                               param_grid,
                               n_jobs=-1,
                               cv=shuffle_split
                              ).fit(X, y)

    best_score = np.round(grid_search.best_score_, 4)

    print(f'Best estimator: {grid_search.best_estimator_}')
    print(f'Best mean cross-validated accuracy: {best_score}')

    return grid_search.best_estimator_, best_score

# %%
shuffle_split = StratifiedShuffleSplit(test_size=0.15, n_splits=10)

# %% [markdown]
# Seven models are trained to predict whether an exoplanets was detected or not:
# - Naive Bayes, which is a baseline for this application,
# - Logistic Regression,
# - C-Support Vector Machines Classification,
# - $k$-Nearest Neighbors,
# - Decision Trees,
# - Random Forest,
# - Stacking CV Classification.

# %% [markdown]
# ### V.1.1 Naive Bayes (Baseline)

# %%
GaussianNB = GaussianNB()

# %%
# %%time

GaussianNB_score = train_classifier(model=GaussianNB, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: GaussianNB
# Parameters: {'priors': None, 'var_smoothing': 1e-09}
# Mean cross-validated accuracy: 0.9812
# Wall time: 2.77 s

# %% [markdown]
# ### V.1.2 Logistic Regression

# %%
LogisticRegression = LogisticRegression()

# %%
# %%time

LogisticRegression_score = train_classifier(model=LogisticRegression, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: LogisticRegression
# Parameters: {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
# Mean cross-validated accuracy: 0.99
# Wall time: 223 ms

# %%
# %%time

penalty = ['l1', 'l2', 'elasticnet', 'none']
C = [0.001, 0.01, 0.1, 1, 10, 100]

param_grid_LogisticRegression = {
    'C': C,
    'penalty': penalty
}

LogisticRegression1, LogisticRegression_score1 = grid_search(
    model=LogisticRegression,
    X=X_train,
    y=y_train,
    param_grid=param_grid_LogisticRegression,
    shuffle_split=shuffle_split
)
# Out:
# Best estimator: LogisticRegression(C=0.001, penalty='none')
# Best mean cross-validated accuracy: 0.9908
# Wall time: 2.02 s

# %% [markdown]
# ### V.1.3 Support Vector Machines

# %%
SVC = SVC(probability=True)

# %% [markdown]
# The `probability` parameter is set to `True` to be able to compute ROC and AUC.

# %%
# %%time

SVC_score = train_classifier(model=SVC, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: SVC
# Parameters: {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# Mean cross-validated accuracy: 0.9888
# Wall time: 2.75 s

# %%
# %%time

C = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
gamma = [0.1, 0.3, 0.5, 0.7, 0.9, 1.0, 'auto', 'scale']
class_weight = ['balanced', None]

param_grid_SVC = {
    'C': C,
    'gamma': gamma,
    'class_weight': class_weight
}

SVC1, SVC_score1 = grid_search(
    model=SVC,
    X=X_train,
    y=y_train,
    param_grid=param_grid_SVC,
    shuffle_split=shuffle_split
)
# Out:
# Best estimator: SVC(C=100, class_weight='balanced', gamma=0.9, probability=True)
# Best mean cross-validated accuracy: 0.9911
# Wall time: 10min 14s

# %% [markdown]
# ### V.1.4 $k$-Nearest Neighbors

# %%
KNeighborsClassifier = KNeighborsClassifier()

# %%
# %%time

KNeighborsClassifier_score = train_classifier(model=KNeighborsClassifier, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: KNeighborsClassifier
# Parameters: {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# Mean cross-validated accuracy: 0.9924
# Wall time: 436 ms

# %%
# %%time

n_neighbors = [2, 4, 8, 16, 32]
p = [1, 2, 3]

param_grid_KNeighborsClassifier = {
    'n_neighbors': n_neighbors,
    'p': p
}

KNeighborsClassifier1, KNeighborsClassifier_score1 = grid_search(
    model=KNeighborsClassifier,
    X=X_train,
    y=y_train,
    param_grid=param_grid_KNeighborsClassifier,
    shuffle_split=shuffle_split
)
# Out:
# Best estimator: KNeighborsClassifier(n_neighbors=8, p=1)
# Best mean cross-validated accuracy: 0.9935
# Wall time: 26.3 s

# %% [markdown]
# ### V.1.5 Decision Trees

# %%
DecisionTreeClassifier = DecisionTreeClassifier()

# %%
# %%time

DecisionTreeClassifier_score = train_classifier(model=DecisionTreeClassifier, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: DecisionTreeClassifier
# Parameters: {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# Mean cross-validated accuracy: 0.9904
# Wall time: 172 ms

# %%
# %%time

criterion = ['gini', 'entropy']
max_depth = [int(x) for x in np.linspace(1, 100, num = 11)]
max_depth.append(None)
max_features = ['sqrt', 'log2', None]
class_weight = ['balanced', None]

param_grid_DecisionTreeClassifier = {
    'criterion': criterion,
    'max_depth': max_depth,
    'max_features': max_features,
    'class_weight': class_weight
}

DecisionTreeClassifier1, DecisionTreeClassifier_score1 = grid_search(
    model=DecisionTreeClassifier,
    X=X_train,
    y=y_train,
    param_grid=param_grid_DecisionTreeClassifier,
    shuffle_split=shuffle_split
)
# Out:
# Best estimator: DecisionTreeClassifier(criterion='entropy', max_depth=90)
# Best mean cross-validated accuracy: 0.9921
# Wall time: 4.96 s

# %% [markdown]
# ### V.1.6 Random Forest

# %%
RandomForestClassifier = RandomForestClassifier()

# %%
# %%time

RandomForestClassifier_score = train_classifier(model=RandomForestClassifier, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: RandomForestClassifier
# Parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Mean cross-validated accuracy: 0.9939
# Wall time: 2.2 s

# %%
# %%time

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1500, num = 15)]
max_depth = [5, 8, 15, 25, 30]
max_depth.append(None)
max_features = ['log2', 'sqrt', None]
    
param_grid_RandomForestClassifier = {
    'n_estimators': n_estimators,
    'max_depth': max_depth,
    'max_features': max_features
}

RandomForestClassifier1, RandomForestClassifier_score1 = grid_search(
    model=RandomForestClassifier,
    X=X_train,
    y=y_train,
    param_grid=param_grid_RandomForestClassifier,
    shuffle_split=shuffle_split
)
# Out:
# Best estimator: RandomForestClassifier(max_depth=15, max_features='log2', n_estimators=1000)
# Best mean cross-validated accuracy: 0.9945
# Wall time: 1h 5min 28s

# %% [markdown]
# ### V.1.7 Stacking CV Classification

# %%
clf1 = KNeighborsClassifier1
clf2 = DecisionTreeClassifier1
clf3 = RandomForestClassifier1
lr = LogisticRegression1

sclf = StackingCVClassifier(classifiers=[clf1, clf2, clf3],
                            meta_classifier=lr,
                            random_state=0)

# %%
# %%time

sclf_score = train_classifier(model=sclf, X=X_train, y=y_train, shuffle_split=shuffle_split)
# Out:
# Trainig of model: StackingCVClassifier
# ...

# %% [markdown]
# ## V.2 Model Evaluation<a class="anchor" id="section5_2"></a>

# %%
def predict(model, X_test):
    """
    Function to predict class labels for samples in test data set
    """
    print(f'Predicting class labels of model: {model.__class__.__name__}')
    y_pred = model.predict(X_test)
    return y_pred

def model_evaluation(model, X_test, y, y_pred):
    """
    Function to compute classification metrics using the F1 score and confusion matrix
    """
    Accuracy_score = accuracy_score(y, y_pred)
    Precision_score = precision_score(y, y_pred)
    Recall_score = recall_score(y, y_pred)
    F1_score = f1_score(y, y_pred)
    Roc_auc_score = roc_auc_score(y, model.predict_proba(X_test)[:, 1])
    
    print(f'Evaluation of model: {model.__class__.__name__}')
    print(f'Accuracy score: {Accuracy_score:.4f}')
    print(f'Precision score: {Precision_score:.4f}')
    print(f'Recall score: {Recall_score:.4f}')
    print(f'F1 score: {F1_score:.4f}')
    print(f'AUC score: {Roc_auc_score:.4f}')
    
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    plt.plot(fpr, tpr, label=f'{model.__class__.__name__}')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')
    plt.show()
    
    class_names = ['CONFIRMED', 'FALSE POSITIVE']
    cm = confusion_matrix(y_target=y, y_predicted=y_pred)
    plot_confusion_matrix(conf_mat=cm,
                          show_absolute=True,
                          show_normed=True,
                          colorbar=True,
                          class_names=class_names
                         )
    plt.title('Confusion matrix')
    plt.show()
    
    return Accuracy_score, Precision_score, Recall_score, F1_score, Roc_auc_score

# %%
Models = []
Accuracy_scores = []
Precision_scores = []
Recall_scores = []
F1_scores = []
AUC_scores = []

# %% [markdown]
# The following evaluation metrics are used to determine the performance of each model:
# - accuracy,
# - precision,
# - recall,
# - $F_{1}$ score,
# - ROC,
# - AUC,
# - confusion matrix.
#
# The model with the highest $F_{1}$ score will be chosen for this application.

# %% [markdown]
# ### V.2.1 Naive Bayes

# %%
y_pred_GaussianNB = predict(model=GaussianNB, X_test=X_test)

Accuracy_score_GaussianNB, Precision_score_GaussianNB, Recall_score_GaussianNB, F1_score_GaussianNB, AUC_score_GaussianNB = \
model_evaluation(model=GaussianNB, X_test=X_test, y=y_test, y_pred=y_pred_GaussianNB)
# Out:
# Predicting class labels of model: GaussianNB
# Evaluation of model: GaussianNB
# Accuracy score: 0.9765
# Precision score: 0.9904
# Recall score: 0.9717
# F1 score: 0.9809
# AUC score: 0.9964

# %%
Models.append(GaussianNB.__class__.__name__)
Accuracy_scores.append(Accuracy_score_GaussianNB)
Precision_scores.append(Precision_score_GaussianNB)
Recall_scores.append(Recall_score_GaussianNB)
F1_scores.append(F1_score_GaussianNB)
AUC_scores.append(AUC_score_GaussianNB)

# %% [markdown]
# ### V.2.2 Logistic Regression

# %%
y_pred_LogisticRegression = predict(model=LogisticRegression1, X_test=X_test)

Accuracy_score_LogisticRegression, Precision_score_LogisticRegression, Recall_score_LogisticRegression, F1_score_LogisticRegression, AUC_score_LogisticRegression = \
model_evaluation(model=LogisticRegression1, X_test=X_test, y=y_test, y_pred=y_pred_LogisticRegression)
# Out:
# Predicting class labels of model: LogisticRegression
# Evaluation of model: LogisticRegression
# Accuracy score: 0.9902
# Precision score: 0.9906
# Recall score: 0.9937
# F1 score: 0.9921
# AUC score: 0.9994

# %%
Models.append(LogisticRegression.__class__.__name__)
Accuracy_scores.append(Accuracy_score_LogisticRegression)
Precision_scores.append(Precision_score_LogisticRegression)
Recall_scores.append(Recall_score_LogisticRegression)
F1_scores.append(F1_score_LogisticRegression)
AUC_scores.append(AUC_score_LogisticRegression)

# %% [markdown]
# ### V.2.3 Support Vector Machines

# %%
y_pred_SVC = predict(model=SVC1, X_test=X_test)

Accuracy_score_SVC, Precision_score_SVC, Recall_score_SVC, F1_score_SVC, AUC_score_SVC = \
model_evaluation(model=SVC1, X_test=X_test, y=y_test, y_pred=y_pred_SVC)
# Out:
# Predicting class labels of model: SVC
# Evaluation of model: SVC
# Accuracy score: 0.9892
# Precision score: 0.9937
# Recall score: 0.9890
# F1 score: 0.9913
# AUC score: 0.9968

# %%
Models.append(SVC.__class__.__name__)
Accuracy_scores.append(Accuracy_score_SVC)
Precision_scores.append(Precision_score_SVC)
Recall_scores.append(Recall_score_SVC)
F1_scores.append(F1_score_SVC)
AUC_scores.append(AUC_score_SVC)

# %% [markdown]
# ### V.2.4 k-Nearest Neighbors

# %%
y_pred_KNeighborsClassifier = predict(model=KNeighborsClassifier1, X_test=X_test)

Accuracy_score_KNeighborsClassifier, Precision_score_KNeighborsClassifier, Recall_score_KNeighborsClassifier, F1_score_KNeighborsClassifier, AUC_score_KNeighborsClassifier = \
model_evaluation(model=KNeighborsClassifier1, X_test=X_test, y=y_test, y_pred=y_pred_KNeighborsClassifier)
# Out:
# Predicting class labels of model: KNeighborsClassifier
# Evaluation of model: KNeighborsClassifier
# Accuracy score: 0.9863
# Precision score: 0.9921
# Recall score: 0.9858
# F1 score: 0.9889
# AUC score: 0.9984

# %%
Models.append(KNeighborsClassifier.__class__.__name__)
Accuracy_scores.append(Accuracy_score_KNeighborsClassifier)
Precision_scores.append(Precision_score_KNeighborsClassifier)
Recall_scores.append(Recall_score_KNeighborsClassifier)
F1_scores.append(F1_score_KNeighborsClassifier)
AUC_scores.append(AUC_score_KNeighborsClassifier)

# %% [markdown]
# ### V.2.5 Decision Trees

# %%
y_pred_DecisionTreeClassifier = predict(model=DecisionTreeClassifier1, X_test=X_test)

Accuracy_score_DecisionTreeClassifier, Precision_score_DecisionTreeClassifier, Recall_score_DecisionTreeClassifier, F1_score_DecisionTreeClassifier, AUC_score_DecisionTreeClassifier = \
model_evaluation(model=DecisionTreeClassifier1, X_test=X_test, y=y_test, y_pred=y_pred_DecisionTreeClassifier)
# Out:
# Predicting class labels of model: DecisionTreeClassifier
# Evaluation of model: DecisionTreeClassifier
# Accuracy score: 0.9922
# Precision score: 0.9968
# Recall score: 0.9906
# F1 score: 0.9937
# AUC score: 0.9927

# %%
Models.append(DecisionTreeClassifier.__class__.__name__)
Accuracy_scores.append(Accuracy_score_DecisionTreeClassifier)
Precision_scores.append(Precision_score_DecisionTreeClassifier)
Recall_scores.append(Recall_score_DecisionTreeClassifier)
F1_scores.append(F1_score_DecisionTreeClassifier)
AUC_scores.append(AUC_score_DecisionTreeClassifier)

# %% [markdown]
# ### V.2.6 Random Forest

# %%
y_pred_RandomForestClassifier = predict(model=RandomForestClassifier1, X_test=X_test)

Accuracy_score_RandomForestClassifier, Precision_score_RandomForestClassifier, Recall_score_RandomForestClassifier, F1_score_RandomForestClassifier, AUC_score_RandomForestClassifier = \
model_evaluation(model=RandomForestClassifier1, X_test=X_test, y=y_test, y_pred=y_pred_RandomForestClassifier)
# Out:
# Predicting class labels of model: RandomForestClassifier
# Evaluation of model: RandomForestClassifier
# Accuracy score: 0.9961
# Precision score: 0.9937
# Recall score: 1.0000
# F1 score: 0.9969
# AUC score: 0.9999

# %%
Models.append(RandomForestClassifier.__class__.__name__)
Accuracy_scores.append(Accuracy_score_RandomForestClassifier)
Precision_scores.append(Precision_score_RandomForestClassifier)
Recall_scores.append(Recall_score_RandomForestClassifier)
F1_scores.append(F1_score_RandomForestClassifier)
AUC_scores.append(AUC_score_RandomForestClassifier)

# %% [markdown]
# ### V.2.7 Stacking CV Classification

# %%
y_pred_sclf = predict(model=sclf, X_test=X_test)

Accuracy_score_sclf, Precision_score_sclf, Recall_score_sclf, F1_score_sclf, AUC_score_sclf = \
model_evaluation(model=sclf, X_test=X_test, y=y_test, y_pred=y_pred_sclf)
# Out:
# Predicting class labels of model: StackingCVClassifier
# Evaluation of model: StackingCVClassifier
# Accuracy score: 0.9932
# Precision score: 0.9937
# Recall score: 0.9953
# F1 score: 0.9945
# AUC score: 0.9986

# %%
Models.append(sclf.__class__.__name__)
Accuracy_scores.append(Accuracy_score_sclf)
Precision_scores.append(Precision_score_sclf)
Recall_scores.append(Recall_score_sclf)
F1_scores.append(F1_score_sclf)
AUC_scores.append(AUC_score_sclf)

# %% [markdown]
# ## V.2.1 Summary of model evaluation<a class="anchor" id="section5_2_1"></a>

# %%
metrics_summary = pd.DataFrame({
    'Model': Models,
    'Accuracy Score': Accuracy_scores,
    'Precision Score': Precision_scores,
    'Recall Score': Recall_scores,
    'F1 Score': F1_scores,
    'AUC Score': AUC_scores
})
metrics_summary.sort_values('F1 Score', ascending=False)
# Out:
#                     Model  Accuracy Score  Precision Score  Recall Score  \
# 5  RandomForestClassifier        0.996090         0.993740      1.000000
# 6    StackingCVClassifier        0.993157         0.993711      0.995276
# 4  DecisionTreeClassifier        0.992180         0.996830      0.990551
# 1      LogisticRegression        0.990225         0.990581      0.993701
# 2                     SVC        0.989247         0.993671      0.988976
# 3    KNeighborsClassifier        0.986315         0.992076      0.985827
# 0              GaussianNB        0.976540         0.990369      0.971654
#
#    F1 Score  AUC Score
# 5  0.996860   0.999858
# 6  0.994493   0.998614
# 4  0.993681   0.992698
# 1  0.992138   0.999363
# 2  0.991318   0.996818
# 3  0.988942   0.998360
# 0  0.980922   0.996392

# %% [markdown]
# Random Forest has the highest $F_{1}$ score, so this is the chosen model.

# %% [markdown]
# # VI. Discovering exoplanets with the chosen model<a class="anchor" id="chapter6"></a>

# %%
def discover_possible_exoplanets(model, X_candidates, candidates):
    # Setting up confirmed and false positive array
    confirmed = []
    false_positive = []
    
    # Predicting the candidate exoplanets
    results = pd.Series(model.predict(X_candidates), index=candidates.index)
    candidates.insert(3, 'koi_disposition_pred', results)
    
    # Looping trough all the planets predictions
    for index, planet in candidates.iterrows():
        if planet['koi_disposition_pred'] == 0:
            confirmed.append({'name': planet['kepoi_name'], 'index': planet.index})
        else:
            false_positive.append({'name': planet['kepoi_name'], 'index': planet.index})

    discovery_rate = float(len(confirmed))/candidates.shape[0]*100

    print(f'\nExoplanets: {len(confirmed)} have been Confirmed!')
    print(f'\nExoplanets: {len(false_positive)} are False Positive!')
    print(f'\nDiscovery Rate: {discovery_rate:.4f}%')

# %% [markdown]
# The model is used with the function above to discover exoplanets.
#
# The code is adapted from [here](https://github.com/mitranos/exoplanets-discovery-machine-learning/blob/ac465cb8439deefe68242d86a1757415e00f4645/machine_learning_approach_to_exoplanet_discovery.ipynb).

# %%
candidates.head()
# Out:
#        kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# 2   10811496  K00753.01         NaN       CANDIDATE        CANDIDATE
# 37  11138155  K00760.01         NaN       CANDIDATE        CANDIDATE
# 58  11818800  K00777.01         NaN       CANDIDATE        CANDIDATE
# 62  11918099  K00780.02         NaN       CANDIDATE        CANDIDATE
# 63   9579641  K00115.03         NaN       CANDIDATE        CANDIDATE
#
#     koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 2       0.000              0              0              0              0
# 37      1.000              0              0              0              0
# 58      0.999              0              0              0              0
# 62      0.993              0              0              0              0
# 63      0.871              0              0              0              0
#
#     ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
candidates.drop(columns = ['kepler_name', 'koi_teq_err1', 'koi_teq_err2'], inplace=True)

# %%
candidates.dropna(axis=0, inplace=True)

# %%
X_candidates = candidates.copy(deep=True)

# %%
X_candidates = X_candidates[importances.index[0:X_train.shape[1]]]

# %%
X_candidates = mm.transform(X_candidates)

# %%
discover_possible_exoplanets(model=RandomForestClassifier1, X_candidates=X_candidates, candidates=candidates)
# Out:
# Exoplanets: 1364 have been Confirmed!
#
# Exoplanets: 423 are False Positive!
#
# Discovery Rate: 76.3290%

# %%
candidates.head()
# Out:
#        kepid kepoi_name koi_disposition  koi_disposition_pred  \
# 2   10811496  K00753.01       CANDIDATE                     1
# 37  11138155  K00760.01       CANDIDATE                     1
# 58  11818800  K00777.01       CANDIDATE                     0
# 62  11918099  K00780.02       CANDIDATE                     0
# 63   9579641  K00115.03       CANDIDATE                     0
#
#    koi_pdisposition  ...  koi_srad_err1  koi_srad_err2         ra        dec  \
# 2         CANDIDATE  ...          0.233         -0.078  297.00482  48.134129
# 37        CANDIDATE  ...          0.173         -0.130  292.16705  48.727589
# 58        CANDIDATE  ...          0.116         -0.095  294.31686  50.080231
# 62        CANDIDATE  ...          0.055         -0.028  293.83331  50.230350
# 63        CANDIDATE  ...          0.157         -0.142  287.88733  46.276241
#
#     koi_kepmag
# 2       15.436
# 37      15.263
# 58      15.487
# 62      15.334
# 63      12.791
#
# [5 rows x 47 columns]

# %% [markdown]
# The model, Random Forest, discovered 1,364 exoplanets, and the rest 423 are false positives, i.e., 76.3290% of the detected astronomical objects are exoplanets according to the model. According to this research, in total there are 3645 exoplanets, not taking into account the removed examples with missing data.
#
# Kepler discovered 2,879 planets in total \[[3](#ref3)\]. Thus, there are 26.6064% more discovered planets than there are actually reported. It is possible that something is not right in the data.

# %%
def check_distributions(feature_train, feature_test, feature_candidates, bins=10):
    fig = plt.subplots(1, 3, figsize=(10,5))
    
    plt.subplot(1,3,1)
    sns.histplot(feature_train, bins=bins)
    plt.xticks(np.arange(0, 1, step=0.1))

    plt.subplot(1,3,2)
    sns.histplot(feature_test, bins=bins)
    plt.xticks(np.arange(0, 1, step=0.1))

    plt.subplot(1,3,3)
    sns.histplot(feature_candidates, bins=bins)
    plt.xticks(np.arange(0, 1, step=0.1))

    plt.show()

# %%
check_distributions(train['koi_score'], test['koi_score'], candidates['koi_score'])

# %%
check_distributions(train['koi_fpflag_ss'], test['koi_fpflag_ss'], candidates['koi_fpflag_ss'])

# %%
check_distributions(train['koi_fpflag_co'], test['koi_fpflag_co'], candidates['koi_fpflag_co'])

# %%
check_distributions(train['koi_fpflag_ec'], test['koi_fpflag_ec'], candidates['koi_fpflag_ec'])

# %%
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(30,30))
plot_tree(
    decision_tree=RandomForestClassifier1.estimators_[0],
    max_depth=3,
    feature_names=importances.index[0:X_train.shape[1]],
    class_names=['CONFIRMED', 'FALSE POSITIVE'],
    filled=True
)
plt.show()

# %%
candidates.loc[candidates['koi_score'] <= 0.735].shape[0], candidates.loc[candidates['koi_score'] >= 0.735].shape[0]
# Out:
# (343, 1444)

# %% [markdown]
# The diagnosis of the problem is that the feature `koi_score` (the disposition score) has the highest importance, and it is the feature used for splitting the tree's root. The diagnostic histograms show that the majority of examples in the candidates data set (more than 1,200) have a value of the disposition score greater than or equal to $0.9$.
#
# The root is split such that if $\text{disposition score}> 0.735$, as shown on the tree plot, those examples are more likely to be exoplanets. The number of such examples is 1,444, and the model spits out 1,364 discovered exoplanets. These numbers are similar, and this might explain why the total number od discovered exoplanets (3645) doesn't make sence, i.e., it is not even remotely close to the published results (so far 2,879) by NASA.
#
# The values of the disposition score are calculated from a Monte Carlo technique such that the score's value is equivalent to the fraction of iterations where the procedure called Robovetter \[[6](#ref6)\] yields a disposition of `CANDIDATE`. Even this procedure gives a higher disposition score to far more detected objects, than there actually are.
#
# In general, the most important features are clustered around a single value in the candidates data set, unlike the exoplanets data set, where the values are clumped around two different values which makes a more noticeable distinction whether it's an exoplanet or not, so the model is indiscriminately classifying objects with higher disposition score as exoplanets, even though it is obvious that's not the case.
#
# It might be the case that Random Forest is not powerful enough to weed out the noise in the data and more advanced techniques are needed, for e.g. deep neural networks, or a new subset of features is needed.

# %% [markdown]
# # VII. References<a class="anchor" id="chapter7"></a>
#
# [1] <a class="anchor" id="ref1"></a>Exoplanetarchive.ipac.caltech.edu. 2020. Kepler Objects Of Interest. [online] Available at: <https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=cumulative> [Accessed 30 August 2020].
#
# [2] <a class="anchor" id="ref2"></a>Exoplanetarchive.ipac.caltech.edu. 2020. Data Columns In Kepler Objects Of Interest Table. [online] Available at: <https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html> [Accessed 30 August 2020].
#
# [3] <a class="anchor" id="ref3"></a>Exoplanetarchive.ipac.caltech.edu. 2020. Data Columns In Kepler Objects Of Interest Table. [online] Available at: <https://exoplanets.nasa.gov/discovery/exoplanet-catalog/> [Accessed 3 December 2021].
#
# [4] <a class="anchor" id="ref4"></a>Müller, A. and Guido, S., 2016. Introduction To Machine Learning With Python: A Guide For Data Scientists. 1st ed. O'Reilly Media.
#
# [5] <a class="anchor" id="ref5"></a>Thakur, A., 2020. Approaching (almost) any machine learning problem. 1st ed. Abhishek Thakur.
#
# [6] <a class="anchor" id="ref6"></a>Jeffrey L. Coughlin et al 2016 ApJS **224** 12
